# %%
from google.colab import files
uploaded=files.upload()

# %%
import pandas as pd
df=pd.read_csv('Churn_Modelling.csv',error_bad_lines=False)
df.head()

# %%
# Classification template

# Importing the libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# Importing the dataset
dataset = pd.read_csv('Churn_Modelling.csv')
X = dataset.iloc[:,3:13].values
y = dataset.iloc[:, 13].values

# Encoding categorical data
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.compose import ColumnTransformer
labelencoder_X_2 = LabelEncoder()
X[:, 2] = labelencoder_X_2.fit_transform(X[:, 2])
ct = ColumnTransformer([("Country", OneHotEncoder(), [1])], remainder = 'passthrough')
X = ct.fit_transform(X)
X= np.vstack(X[:, :]).astype(float) #optional
X=X[:,1:]



# Splitting the dataset into the Training set and Test set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# Feature Scaling
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %% [markdown]
# # **Test 1**

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense

# Initializing the ANN
classifier = Sequential() 

# Adding the input layer and first hidden layer
classifier.add(Dense(units=6,kernel_initializer='uniform',activation='relu',input_dim=11))

# Adding second layer
classifier.add(Dense(units=6,kernel_initializer='uniform',activation='relu'))

# Adding output layer
classifier.add(Dense(units=1,kernel_initializer='uniform',activation='sigmoid'))


# Compiling the ANN
classifier.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

# Fitting classifier to the Training set
classifier.fit(X_train,y_train,batch_size=32,epochs=100)

# Create your classifier here

# Predicting the Test set results
y_pred = classifier.predict(X_test)
y_pred = (y_pred > 0.5)

# Making the Confusion Matrix
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)
# Out:
# Epoch 1/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.5678 - accuracy: 0.7946
# Epoch 2/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.4383 - accuracy: 0.7960
# Epoch 3/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.4309 - accuracy: 0.7960
# Epoch 4/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.4277 - accuracy: 0.7960
# Epoch 5/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.4244 - accuracy: 0.7960
# Epoch 6/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.4205 - accuracy: 0.8166
# Epoch 7/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.4166 - accuracy: 0.8249
# Epoch 8/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.4131 - accuracy: 0.8304
# Epoch 9/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.4101 - accuracy: 0.8335
# Epoch 10/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.4076 - accuracy: 0.8342
# Epoch 11/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.4056 - accuracy: 0.8354
# Epoch 12/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.4041 - accuracy: 0.8344
# Epoch 13/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.4029 - accuracy: 0.8335
# Epoch 14/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.4016 - accuracy: 0.8349
# Epoch 15/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.4009 - accuracy: 0.8359
# Epoch 16/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3998 - accuracy: 0.8351
# Epoch 17/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3992 - accuracy: 0.8340
# Epoch 18/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3987 - accuracy: 0.8351
# Epoch 19/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3980 - accuracy: 0.8350
# Epoch 20/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3970 - accuracy: 0.8344
# Epoch 21/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3970 - accuracy: 0.8364
# Epoch 22/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3967 - accuracy: 0.8356
# Epoch 23/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3964 - accuracy: 0.8354
# Epoch 24/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3963 - accuracy: 0.8353
# Epoch 25/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3962 - accuracy: 0.8346
# Epoch 26/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3955 - accuracy: 0.8353
# Epoch 27/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3956 - accuracy: 0.8350
# Epoch 28/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3952 - accuracy: 0.8339
# Epoch 29/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3952 - accuracy: 0.8345
# Epoch 30/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3944 - accuracy: 0.8356
# Epoch 31/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3946 - accuracy: 0.8354
# Epoch 32/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3947 - accuracy: 0.8336
# Epoch 33/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3944 - accuracy: 0.8347
# Epoch 34/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3939 - accuracy: 0.8345
# Epoch 35/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3941 - accuracy: 0.8351
# Epoch 36/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3938 - accuracy: 0.8353
# Epoch 37/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3939 - accuracy: 0.8355
# Epoch 38/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3938 - accuracy: 0.8347
# Epoch 39/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3936 - accuracy: 0.8344
# Epoch 40/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3937 - accuracy: 0.8360
# Epoch 41/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3934 - accuracy: 0.8363
# Epoch 42/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3933 - accuracy: 0.8347
# Epoch 43/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3933 - accuracy: 0.8370
# Epoch 44/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3933 - accuracy: 0.8356
# Epoch 45/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3929 - accuracy: 0.8364
# Epoch 46/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3928 - accuracy: 0.8353
# Epoch 47/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3924 - accuracy: 0.8372
# Epoch 48/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3921 - accuracy: 0.8371
# Epoch 49/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3916 - accuracy: 0.8382
# Epoch 50/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3910 - accuracy: 0.8372
# Epoch 51/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3906 - accuracy: 0.8381
# Epoch 52/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3894 - accuracy: 0.8386
# Epoch 53/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3883 - accuracy: 0.8393
# Epoch 54/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3867 - accuracy: 0.8399
# Epoch 55/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3856 - accuracy: 0.8393
# Epoch 56/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3839 - accuracy: 0.8421
# Epoch 57/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3821 - accuracy: 0.8414
# Epoch 58/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3795 - accuracy: 0.8414
# Epoch 59/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3766 - accuracy: 0.8432
# Epoch 60/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3734 - accuracy: 0.8440
# Epoch 61/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3700 - accuracy: 0.8454
# Epoch 62/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3662 - accuracy: 0.8487
# Epoch 63/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3615 - accuracy: 0.8497
# Epoch 64/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3594 - accuracy: 0.8530
# Epoch 65/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3562 - accuracy: 0.8519
# Epoch 66/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3539 - accuracy: 0.8536
# Epoch 67/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3521 - accuracy: 0.8549
# Epoch 68/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3509 - accuracy: 0.8558
# Epoch 69/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3487 - accuracy: 0.8574
# Epoch 70/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3477 - accuracy: 0.8566
# Epoch 71/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3467 - accuracy: 0.8575
# Epoch 72/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3467 - accuracy: 0.8561
# Epoch 73/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3452 - accuracy: 0.8583
# Epoch 74/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3447 - accuracy: 0.8587
# Epoch 75/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3445 - accuracy: 0.8601
# Epoch 76/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3446 - accuracy: 0.8599
# Epoch 77/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3436 - accuracy: 0.8590
# Epoch 78/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3432 - accuracy: 0.8579
# Epoch 79/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3433 - accuracy: 0.8590
# Epoch 80/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3420 - accuracy: 0.8602
# Epoch 81/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3421 - accuracy: 0.8601
# Epoch 82/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3412 - accuracy: 0.8602
# Epoch 83/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3413 - accuracy: 0.8591
# Epoch 84/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3414 - accuracy: 0.8590
# Epoch 85/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3409 - accuracy: 0.8604
# Epoch 86/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3411 - accuracy: 0.8606
# Epoch 87/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3404 - accuracy: 0.8625
# Epoch 88/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3405 - accuracy: 0.8581
# Epoch 89/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3408 - accuracy: 0.8606
# Epoch 90/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3394 - accuracy: 0.8601
# Epoch 91/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3400 - accuracy: 0.8619
# Epoch 92/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3396 - accuracy: 0.8595
# Epoch 93/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3394 - accuracy: 0.8626
# Epoch 94/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3403 - accuracy: 0.8604
# Epoch 95/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3396 - accuracy: 0.8599
# Epoch 96/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3396 - accuracy: 0.8599
# Epoch 97/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3388 - accuracy: 0.8602
# Epoch 98/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3398 - accuracy: 0.8589
# Epoch 99/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3390 - accuracy: 0.8596
# Epoch 100/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3394 - accuracy: 0.8611

# %%
print(cm)
# Out:
# [[1500   95]
#  [ 192  213]]

# %%
(1500+213)/2000
# Out:
# 0.8565

# %%
#accuracy
(1506+211)/2000
# Out:
# 0.8585

# %% [markdown]
# # **Test 2**

# %%
from keras.models import Sequential
from keras.layers import Dense

from keras.wrappers.scikit_learn import KerasClassifier
from sklearn.model_selection import  cross_val_score

def build_classifier():
    classifier = Sequential() 
    classifier.add(Dense(units=6,kernel_initializer='uniform',activation='relu',input_dim=11))
    classifier.add(Dense(units=6,kernel_initializer='uniform',activation='relu'))
    classifier.add(Dense(units=1,kernel_initializer='uniform',activation='sigmoid'))
    classifier.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])
    return classifier

# %%
classifier= KerasClassifier(build_fn=build_classifier,batch_size=32,nb_epoch=100)
accuracies=cross_val_score(estimator=classifier, X=X_train,y=y_train,cv=10,n_jobs=-1)
mean=accuracies.mean()
variance=accuracies.std()

# %%
print(accuracies)
print(mean)
print(variance)
# Out:
# [0.78625    0.79000002 0.80000001 0.78250003 0.81625003 0.81
#  0.78750002 0.79374999 0.79874998 0.79500002]
# 0.7960000097751617
# 0.010105690527913859

# %% [markdown]
# # **Test 3**
# It has taken 10min on the google GPUs

# %%
from keras.models import Sequential
from keras.layers import Dense

from keras.wrappers.scikit_learn import KerasClassifier
from sklearn.model_selection import  cross_val_score

def build_classifier():
    classifier = Sequential() 
    classifier.add(Dense(units=6,activation='relu',input_dim=11))
    classifier.add(Dense(units=6,activation='relu'))
    classifier.add(Dense(units=1,activation='sigmoid'))
    classifier.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])
    return classifier

# %%
classifier= KerasClassifier(build_fn=build_classifier,batch_size=32,epochs=100)
accuracies=cross_val_score(estimator=classifier, X=X_train,y=y_train,cv=10,n_jobs=-1)
mean=accuracies.mean()
variance=accuracies.std()

# %%
print(accuracies)
print(mean)
print(variance)
# Out:
# [0.86000001 0.85750002 0.86500001 0.85500002 0.88499999 0.85500002
#  0.86000001 0.84625    0.84500003 0.87124997]
# 0.8600000083446503
# 0.011166345735238089
